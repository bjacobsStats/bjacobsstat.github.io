# %% [raw]
# ---
# title: "Benjamin Jacobs"
# ---

# %% [markdown]
# ```{css, echo=FALSE}
# @font-face {
#   font-family: UncialAntiqua;
#   src: url('./UncialAntiqua-Regular.ttf') format('truetype');
#   font-weight: normal;
#   font-style: normal;
# }
# @font-face {
#   font-family: IBMPlexMono;
#   src: url('./IBMPlexMono-Medium.ttf') format('truetype');
#   font-weight: normal;
#   font-style: normal;
# }
# h1 {
#   background-color: #F0F0F0;
#     font-family: UncialAntiqua;
#         font-weight: Bold;
#         color: #331800;
# }
# div {
#   background-color: #F0F0F0;
#     font-family: IBMPlexMono;
#     font-size: 18px;
#             color: #331800;
# }
# html {
#   background-color: #F0F0F0;
#     font-family: IBMPlexMono;
#     font-size: 24px;
#             color: #331800;
# }
# body {
#   background-color: #F0F0F0;
#           color: #331800;
#
#
#           /*----------------NAVBAR ---------------*/
# .navbar-default {
#     background-color: #F0F0F0;
# }
#
# .navbar-default .navbar-nav>.open>a,
# .navbar-default .navbar-nav>.active>a,
# a.dropdown-toggle:hover {
#   background-color: #F0F0F0 !important;
# }
#
# /* Dropdown menu color */
# .navbar-default .dropdown-menu {
#   background-color: #F0F0F0;
# }
#
# /* Dropdown menu hover color */
#   .navbar-default .dropdown-menu>li>a:hover {
#     background-color: #F0F0F0;
#   }
#
# /* Navbar Links when hovered*/
# .navbar-default .dropdown-menu>.active>a
# .navbar-default .navbar-nav>.active>a:hover,
# .navbar-default .navbar-nav:hover,
# .navbar-default .navbar-nav>li>a:hover,
# a.navbar-brand:hover {
#   color: #F0F0F0 !important;
#   background-color: #F0F0F0;
# }
#
# }
# ```
#
#
#
#  |  |  |
# | --- | --- | --- | --- |
# Mainpage | [CV/Resume](./CV_Resume) | [Gallery](./Gallery) | [Miscellanea](./Miscellanea)
#
#
# ## Welcome!
#
# <br>
#
# ## About Me
#
# I am a PhD student in the Department of Statistics at Iowa State University. I previously studied Statistics at the University of Iowa (BS '18, MS '19). I then worked for a few years as a Biostatistician at the Center for International Blood and Marrow Transplant Research (CIBMTR) at the Medical College of Wisconsin.
#
# My research interests include Bayesian statistics, probability, and statistical computing and graphics.
#
#
#
# ## External Links
#
#
# [Iowa State University Stat Dept](https://www.stat.iastate.edu/)
#
# [University of Iowa Stat and Ac Sci Dept](https://stat.uiowa.edu/)
#
# [CIBMTR](https://www.cibmtr.org/Pages/index.aspx)
